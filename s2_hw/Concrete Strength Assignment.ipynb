# %% [markdown]
# # Assignment: Compresive Strength Concrete Problem
#
#
# ### Abstract:
#
# Concrete is the most important material in civil engineering. The concrete compressive strength (concrete strength to bear the load) is a highly nonlinear function of age and ingredients.  <br><br>
#
# <table border="1"  cellpadding="6" bordercolor="red">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">1030</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">9</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">2007-08-03</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Regression</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">231464</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ###  Description:
# | Features Name | Data Type | Measurement | Description |
# | -- | -- | -- | -- |
# Cement (component 1) | quantitative | kg in a m3 mixture | Input Variable
# Blast Furnace Slag (component 2) | quantitative | kg in a m3 mixture | Input Variable
# Fly Ash (component 3) | quantitative | kg in a m3 mixture | Input Variable
# Water (component 4) | quantitative | kg in a m3 mixture | Input Variable
# Superplasticizer (component 5) | quantitative | kg in a m3 mixture | Input Variable
# Coarse Aggregate (component 6) | quantitative | kg in a m3 mixture | Input Variable
# Fine Aggregate (component 7) | quantitative | kg in a m3 mixture | Input Variable
# Age | quantitative | Day (1~365) | Input Variable
# Concrete compressive strength | quantitative | MPa | Output Variable
#
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature )
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
# - Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
# - Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# - Train the Model with Epochs (100) and validate it
# - If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/compresive_strength_concrete.csv)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras import models
from tensorflow.keras import layers
import tensorflow as tf
df=pd.read_csv("concrete.csv")

# %%
df=df.fillna(df.mean())

# %%
df=(df-df.mean())/df.std()

# %%
train,test,validate=np.split(df.sample(frac=1),[515,824])

# %%
model = models.Sequential()
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(6,activation="relu"))
model.add(layers.Dense(1,activation="sigmoid"))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
model.fit(train.iloc[:,0:8],train.iloc[:,8],epochs=100)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 2ms/step - loss: 0.9790 - mae: 0.8078
# Epoch 2/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.7726 - mae: 0.7179
# Epoch 3/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6957 - mae: 0.6733
# Epoch 4/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6047 - mae: 0.6198
# Epoch 5/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6893 - mae: 0.6663
# Epoch 6/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6240 - mae: 0.6286
# Epoch 7/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6021 - mae: 0.6228
# Epoch 8/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6659 - mae: 0.6449
# Epoch 9/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5302 - mae: 0.5697
# Epoch 10/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6427 - mae: 0.6410
# Epoch 11/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6061 - mae: 0.6138
# Epoch 12/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6017 - mae: 0.6162
# Epoch 13/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6202 - mae: 0.6175
# Epoch 14/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5681 - mae: 0.5913
# Epoch 15/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5714 - mae: 0.5873
# Epoch 16/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6140 - mae: 0.6109
# Epoch 17/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6008 - mae: 0.6021
# Epoch 18/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5475 - mae: 0.5615
# Epoch 19/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5519 - mae: 0.5701
# Epoch 20/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6785 - mae: 0.6528
# Epoch 21/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5578 - mae: 0.5702
# Epoch 22/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6278 - mae: 0.6121
# Epoch 23/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5467 - mae: 0.5626
# Epoch 24/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6168 - mae: 0.6182
# Epoch 25/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5185 - mae: 0.5361
# Epoch 26/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5423 - mae: 0.5629
# Epoch 27/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5465 - mae: 0.5737
# Epoch 28/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5949 - mae: 0.6001
# Epoch 29/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5336 - mae: 0.5586
# Epoch 30/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5863 - mae: 0.5765
# Epoch 31/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5878 - mae: 0.5848
# Epoch 32/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5432 - mae: 0.5606
# Epoch 33/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5775 - mae: 0.5741
# Epoch 34/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5564 - mae: 0.5727
# Epoch 35/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6142 - mae: 0.6024
# Epoch 36/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5586 - mae: 0.5623
# Epoch 37/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6057 - mae: 0.5918
# Epoch 38/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5621 - mae: 0.5777
# Epoch 39/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5715 - mae: 0.5662
# Epoch 40/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5158 - mae: 0.5355
# Epoch 41/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5458 - mae: 0.5649
# Epoch 42/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5298 - mae: 0.5406
# Epoch 43/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5417 - mae: 0.5607
# Epoch 44/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5632 - mae: 0.5677
# Epoch 45/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4868 - mae: 0.512 - 0s 1ms/step - loss: 0.5245 - mae: 0.5401
# Epoch 46/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5490 - mae: 0.5628
# Epoch 47/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6020 - mae: 0.5874
# Epoch 48/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6006 - mae: 0.5777
# Epoch 49/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5985 - mae: 0.5859
# Epoch 50/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5852 - mae: 0.5822
# Epoch 51/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5923 - mae: 0.5793
# Epoch 52/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5727 - mae: 0.5682
# Epoch 53/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5347 - mae: 0.5501
# Epoch 54/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5419 - mae: 0.5531
# Epoch 55/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5352 - mae: 0.5484
# Epoch 56/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5403 - mae: 0.5346
# Epoch 57/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5970 - mae: 0.5811
# Epoch 58/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5754 - mae: 0.5762
# Epoch 59/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5411 - mae: 0.5559
# Epoch 60/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5589 - mae: 0.5563
# Epoch 61/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5511 - mae: 0.5466
# Epoch 62/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5527 - mae: 0.5563
# Epoch 63/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5887 - mae: 0.5809
# Epoch 64/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5507 - mae: 0.5510
# Epoch 65/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5768 - mae: 0.5670
# Epoch 66/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5529 - mae: 0.5514
# Epoch 67/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5684 - mae: 0.5606
# Epoch 68/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5085 - mae: 0.5261
# Epoch 69/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5429 - mae: 0.5425
# Epoch 70/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5563 - mae: 0.5501
# Epoch 71/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5651 - mae: 0.5574
# Epoch 72/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5158 - mae: 0.5382
# Epoch 73/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5516 - mae: 0.5531
# Epoch 74/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5594 - mae: 0.5532
# Epoch 75/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5416 - mae: 0.5484
# Epoch 76/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5801 - mae: 0.5564
# Epoch 77/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5828 - mae: 0.5689
# Epoch 78/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5272 - mae: 0.5277
# Epoch 79/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5691 - mae: 0.5509
# Epoch 80/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5795 - mae: 0.5628
# Epoch 81/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5751 - mae: 0.5600
# Epoch 82/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5598 - mae: 0.5485
# Epoch 83/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5157 - mae: 0.5275
# Epoch 84/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5604 - mae: 0.5495
# Epoch 85/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5335 - mae: 0.5418
# Epoch 86/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5424 - mae: 0.5504
# Epoch 87/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5921 - mae: 0.5835
# Epoch 88/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5464 - mae: 0.5513
# Epoch 89/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5175 - mae: 0.5296
# Epoch 90/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5633 - mae: 0.5485
# Epoch 91/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5409 - mae: 0.5418
# Epoch 92/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5820 - mae: 0.5702
# Epoch 93/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5585 - mae: 0.5583
# Epoch 94/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5885 - mae: 0.5634
# Epoch 95/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5365 - mae: 0.5409
# Epoch 96/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5378 - mae: 0.5387
# Epoch 97/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5860 - mae: 0.5634
# Epoch 98/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5430 - mae: 0.5412
# Epoch 99/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5815 - mae: 0.5608
# Epoch 100/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5974 - mae: 0.5717

# %%
train_data=train.iloc[:,:8]
test_data=test.iloc[:,:8]
test_targets=test.iloc[:,8]
train_targets=train.iloc[:,8]
import numpy as np
k=4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print('processing fold #', i)
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
    [train_data[:i * num_val_samples],
    train_data[(i + 1) * num_val_samples:]],
    axis=0)
    partial_train_targets = np.concatenate(
    [train_targets[:i * num_val_samples],
    train_targets[(i + 1) * num_val_samples:]],
    axis=0)
    model.fit(partial_train_data, partial_train_targets,
    epochs=num_epochs, batch_size=1, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
np.mean(all_scores)
# Out:
# 0.5931825637817383

# %%
model.evaluate(test.iloc[:,:8],test.iloc[:,8])
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6476 - mae: 0.6408
# [0.6476121544837952, 0.6408246755599976]

# %%
model.predict(validate.iloc[:,:8])
# Out:
# array([[0.0000000e+00],
#        [0.0000000e+00],
#        [7.4603856e-03],
#        [0.0000000e+00],
#        [9.6121633e-01],
#        [9.9024379e-01],
#        [1.5989134e-26],
#        [4.6628714e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [6.7441458e-01],
#        [0.0000000e+00],
#        [1.9664844e-21],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [2.5855568e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9677622e-01],
#        [9.9999970e-01],
#        [9.7622433e-38],
#        [9.9999559e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [8.2993674e-01],
#        [9.9999911e-01],
#        [6.4029604e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [5.6767286e-20],
#        [4.4334060e-01],
#        [0.0000000e+00],
#        [3.7369132e-03],
#        [2.0266247e-01],
#        [0.0000000e+00],
#        [4.5601962e-09],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [2.5400793e-27],
#        [5.4147836e-37],
#        [1.0000000e+00],
#        [6.4267802e-01],
#        [9.9999911e-01],
#        [2.5714220e-28],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.8091185e-01],
#        [8.3690572e-32],
#        [0.0000000e+00],
#        [1.6888718e-27],
#        [6.3560069e-01],
#        [4.1464090e-02],
#        [6.1691999e-03],
#        [4.1108264e-22],
#        [9.9995166e-01],
#        [9.5457661e-01],
#        [1.6460282e-01],
#        [9.8983252e-01],
#        [8.1858683e-01],
#        [2.2067818e-01],
#        [2.2745132e-04],
#        [9.7517735e-01],
#        [7.4260712e-01],
#        [0.0000000e+00],
#        [9.9997771e-01],
#        [8.9525372e-02],
#        [3.3321118e-10],
#        [0.0000000e+00],
#        [4.8468214e-23],
#        [8.2733226e-01],
#        [4.2608380e-03],
#        [0.0000000e+00],
#        [1.3414058e-19],
#        [6.3575238e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [5.1850878e-14],
#        [8.7795911e-08],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9996597e-01],
#        [6.0075521e-04],
#        [9.9982727e-01],
#        [3.5185486e-02],
#        [1.7453739e-01],
#        [1.8022240e-08],
#        [2.0664194e-01],
#        [1.0498194e-04],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [7.7581853e-01],
#        [9.9791574e-01],
#        [1.5426314e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [2.5844097e-01],
#        [9.9999720e-01],
#        [9.9999428e-01],
#        [6.8790817e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.0395389e-04],
#        [8.7564290e-03],
#        [4.8835158e-01],
#        [8.7669575e-01],
#        [9.9998188e-01],
#        [0.0000000e+00],
#        [9.9977255e-01],
#        [0.0000000e+00],
#        [5.5503547e-03],
#        [9.9982107e-01],
#        [3.3487934e-01],
#        [8.7231100e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.1507015e-04],
#        [0.0000000e+00],
#        [5.0459976e-22],
#        [9.1304930e-05],
#        [1.2585327e-01],
#        [9.9995452e-01],
#        [1.0000000e+00],
#        [6.3812804e-01],
#        [2.7049184e-03],
#        [0.0000000e+00],
#        [4.1910806e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9864006e-01],
#        [8.0256081e-01],
#        [5.2996635e-02],
#        [9.7548187e-01],
#        [9.9168378e-01],
#        [2.1845609e-01],
#        [9.9992585e-01],
#        [4.2569339e-03],
#        [1.0975265e-31],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [5.2481943e-01],
#        [4.9996884e-10],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9997282e-01],
#        [0.0000000e+00],
#        [1.0000000e+00],
#        [4.7669125e-01],
#        [0.0000000e+00],
#        [1.6209780e-20],
#        [9.9933999e-09],
#        [9.9999201e-01],
#        [3.9589363e-06],
#        [9.9949729e-01],
#        [2.0796746e-01],
#        [9.1261154e-01],
#        [2.4560693e-06],
#        [9.9984038e-01],
#        [1.0103929e-12],
#        [9.9852705e-01],
#        [2.3618111e-05],
#        [9.9826360e-01],
#        [2.0509005e-01],
#        [2.7568604e-28],
#        [0.0000000e+00],
#        [9.9999988e-01],
#        [9.9303484e-02],
#        [1.1284947e-03],
#        [9.9954605e-01],
#        [0.0000000e+00],
#        [9.2124069e-01],
#        [0.0000000e+00],
#        [9.9995261e-01],
#        [8.8055436e-21],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.2682855e-02],
#        [0.0000000e+00],
#        [4.7301040e-23],
#        [3.6331713e-02],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.5212328e-01],
#        [1.4403006e-32],
#        [9.3436074e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.4697636e-37],
#        [7.7051139e-01],
#        [0.0000000e+00],
#        [7.3077530e-01],
#        [0.0000000e+00],
#        [9.9823403e-01],
#        [6.4630625e-13],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.9999714e-01],
#        [4.0326887e-20],
#        [4.0796995e-02]], dtype=float32)
