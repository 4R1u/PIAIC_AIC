# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam,SGD
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
df=pd.read_csv("ionosphere_data.csv")

# %%
df=df.fillna(df.mean())

# %%
df=df.sample(frac=1)

# %%
X=df.iloc[:,0:-1]
Y=df.iloc[:,-1]

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,Y,test_size=0.4)

# %%
train_Y=train_Y.replace('g',1.0)
train_Y=train_Y.replace('b',0.0)
test_Y=test_Y.replace('g',1.0)
test_Y=test_Y.replace('b',0.0)

# %%
model = Sequential()
model.add(Dense(16, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(.2))
model.add(Dropout(.1))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
r=model.fit(train_X, train_Y,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.7237 - accuracy: 0.4361
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.5558
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6288 - accuracy: 0.6949
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.7390
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.7431
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.7464
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5202 - accuracy: 0.7636
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.7830
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4821 - accuracy: 0.8112
# Epoch 10/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4475 - accuracy: 0.8206
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8888
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8808
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8744
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3668 - accuracy: 0.8937
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8971
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.9066
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3014 - accuracy: 0.9299
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.9062
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9439
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.9142
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.9029
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9237
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9378
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.9179
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2358 - accuracy: 0.9232
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9404
# Epoch 27/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2266 - accuracy: 0.9125
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9488
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1753 - accuracy: 0.9573
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9422
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9642
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9465
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9467
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9515
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1375 - accuracy: 0.9621
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9545
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9479
# Epoch 38/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.9668
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 0.9712
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9592
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9676
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9820
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.9765
# Epoch 44/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9776
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.9781
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9715
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9600
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9912
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9789
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9901
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9833
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9889
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9717
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9698
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0576 - accuracy: 0.9854
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.9852
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 0.9739
# Epoch 58/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9885
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9843
# Epoch 60/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9893
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9716
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9825
# Epoch 63/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.96 - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9843
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9773
# Epoch 65/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9946
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9798
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 0.9856
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9920
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9931
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9856
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9874
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9931
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9856
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9892
# Epoch 75/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9974
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9869
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9951
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9964
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9951
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9951
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9925
# Epoch 83/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9964
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9974
# Epoch 85/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9892
# Epoch 86/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9982
# Epoch 87/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9982
# Epoch 89/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9892
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9856
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9964
# Epoch 93/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000

# %%
model.evaluate(test_X,test_Y)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9574
# [0.1635734587907791, 0.957446813583374]

# %%
model.predict(train_X)
# Out:
# array([[3.70270312e-02],
#        [1.04524099e-06],
#        [9.99590039e-01],
#        [1.30436152e-01],
#        [9.96600389e-01],
#        [9.93487954e-01],
#        [1.69996310e-05],
#        [9.99565244e-01],
#        [9.97133970e-01],
#        [9.93146181e-01],
#        [9.99673724e-01],
#        [3.03387642e-04],
#        [9.93903160e-01],
#        [9.97652650e-01],
#        [1.27231402e-07],
#        [9.73809719e-01],
#        [9.92578864e-01],
#        [3.00947428e-01],
#        [1.15669927e-08],
#        [9.98879552e-01],
#        [4.37370763e-05],
#        [9.99722242e-01],
#        [9.77504253e-03],
#        [9.99876261e-01],
#        [9.79437649e-01],
#        [9.97269571e-01],
#        [9.97985840e-01],
#        [6.44257412e-08],
#        [9.87254024e-01],
#        [9.65068698e-01],
#        [9.99147594e-01],
#        [9.99737740e-01],
#        [9.77409482e-01],
#        [9.82989609e-01],
#        [9.99298930e-01],
#        [9.99512732e-01],
#        [9.99523640e-01],
#        [9.97602820e-01],
#        [2.02924013e-04],
#        [9.98200893e-01],
#        [9.99666691e-01],
#        [9.98711884e-01],
#        [9.99848604e-01],
#        [2.35419571e-02],
#        [9.96029019e-01],
#        [9.50545967e-01],
#        [9.91191864e-01],
#        [3.20208073e-03],
#        [9.86340404e-01],
#        [9.98403251e-01],
#        [9.99696076e-01],
#        [9.99468803e-01],
#        [9.99798894e-01],
#        [9.99511123e-01],
#        [9.99239981e-01],
#        [9.99610841e-01],
#        [5.19868731e-03],
#        [9.99611974e-01],
#        [6.59736991e-03],
#        [8.59284410e-05],
#        [9.98636723e-01],
#        [2.62773428e-05],
#        [8.20636749e-04],
#        [9.99512494e-01],
#        [9.99717593e-01],
#        [1.24543905e-04],
#        [7.73260035e-06],
#        [1.12110183e-06],
#        [9.99622226e-01],
#        [9.98621047e-01],
